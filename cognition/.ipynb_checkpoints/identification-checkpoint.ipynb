# %% [markdown]
# # Amazon Rekognition: Face Identification

# %%
import boto3
import botocore
import numpy as np
from skimage import io
from os import getcwd, listdir
import time

PROFILE = "default"
BUCKET = "poc-images-rekognition"
DATA_FOLDER = "../Data/Recognition/"
SAVE_FOLDER = DATA_FOLDER + "Identification/"
REGION = "eu-west-1"
S3_FOLDER = "Recognition/"

# %%
session = boto3.Session(profile_name=PROFILE)
s3 = session.client("s3")
rekognition = session.client("rekognition", REGION)

# %%
files = listdir(LOCAL_FOLDER, )
images_names = sorted([f for f in files if f.endswith('.jpg')])
images = [io.imread(LOCAL_FOLDER + image) for image in images_names]

# %%
def aws_identification(source_bucket, source_image, target_bucket, target_image, rekognition_client, threshold=80):
    response = rekognition_client.compare_faces(
        SourceImage={
            "S3Object": {
                "Bucket": source_bucket,
                "Name": source_image,
            }
        },
        TargetImage={
            "S3Object": {
                "Bucket": target_bucket,
                "Name": target_image,
            }
        },
        SimilarityThreshold = threshold,
    )
    match = response['FaceMatches']
    
    if not match: 
        identification_ok = False
    else:
        identification_ok = True
        
    return identification_ok

# %%
def concatenate_images(images, verbose = False): 
    n_images = len(images)
    images_dim = np.asarray([images[i].shape for i in range(0, n_images)])
    max_rows = max(images_dim[:,0])
    max_cols = max(images_dim[:,1])
    pad_images = list()
    
    if verbose:  
        print("")
        print("############################################################")
        print("Images dimensions: ") 
        print(images_dim)
        print("")
        print("Paddings: " + "[pad_top, pad_bottom, pad_left, pad_right]")
    
    for i in range(0, n_images):
        n_rows = images[i].shape[0]
        n_cols = images[i].shape[1]
        pad_top = pad_bottom = (max_rows - n_rows)//2
        pad_left = pad_right = (max_cols - n_cols)//2
        
        if verbose:
            print(str(i) + ". " + str([pad_top, pad_bottom, pad_left, pad_right]))
        
        if (pad_top + pad_bottom + pad_left + pad_right) !=0:
            
            if (pad_top + pad_bottom + n_rows) != max_rows:
                pad_top += 1
            
            if (pad_left + pad_right + n_cols) != max_cols:
                pad_left += 1
             
            pad_image = np.lib.pad(images[i], 
                            (
                                (pad_top, pad_bottom),
                                (pad_left, pad_right),
                                (0,0)
                            ), 
                            'constant', 
                            constant_values = 255) 
            pad_images.append(pad_image)
            
        else:
            pad_images.append(images[i])

    pad_images = np.asarray(pad_images)
    concat_images = np.hstack(pad_images)
    
    if verbose:
            print("################################################################")
    
    return concat_images

# %%
equal_image = io.imread('../Data/Symbols/Equal.jpg')
if equal_image.ndim != 3: 
    equal_image = np.repeat(equal_image[:, :, np.newaxis], 3, axis = 2)

not_equal_image = io.imread('../Data/Symbols/NotEqual.jpg')
if not_equal_image.ndim != 3: 
    not_equal_image = np.repeat(not_equal_image[:, :, np.newaxis], 3, axis = 2)

# %%
registered_people_images = images[::5]
registered_people_images_names = images_names[::5]
unknown_people_images = images[1::5]
unknown_people_images_names = images_names[1::5]
n_different_people = 20

dlib_times = list()
aws_times = list()
dlib_success = 0
aws_success = 0
count = 0

# win = dlib.image_window()

for i in range(0, n_different_people):
    
    target_image = registered_people_images[i]
    target_image_name = registered_people_images_names[i]
  
    for j in range(0, n_different_people):
        
        source_image = unknown_people_images[j]
        source_image_name = unknown_people_images_names[j]        
            
        count += 1
        print("{}. Comparing face {} with {}".format(count, source_image_name, target_image_name))
        t1 = time.time()
        dlib_comparison = dlib_identification(source_image, target_image)
        t2 = time.time()
        aws_comparison = aws_identification(BUCKET, S3_FOLDER + source_image_name, 
                                            BUCKET, S3_FOLDER + target_image_name, 
                                            rekognition)
        t3 = time.time()

        dlib_times.append(t2-t1)
        aws_times.append(t3-t2)

        if dlib_comparison is True:
            dlib_success += 1
            dlib_result = concatenate_images([source_image, equal_image, target_image])
        else:
            dlib_result = concatenate_images([source_image, not_equal_image, target_image])

        if aws_comparison is True:
            aws_success += 1
            aws_result = concatenate_images([source_image, equal_image, target_image])
        else:
            aws_result = concatenate_images([source_image, not_equal_image, target_image])

        io.imsave(SAVE_FOLDER + "dlib_comparison_" + str(count) + ".jpg", dlib_result)
        io.imsave(SAVE_FOLDER + "aws_comparison_" + str(count) + ".jpg", aws_result)

        # win.clear_overlay()
        # win.set_image(image)
        # win.add_overlay(dlib_bounding_checks, dlib.rgb_pixel(0,0,255))
        # win.add_overlay(aws_bounding_checks)
# Out:
# 1. Comparing face and_exp.13.jpg with and_exp.1.jpg
# 2. Comparing face ant_exp.13.jpg with and_exp.1.jpg
# 3. Comparing face chr_exp.13.jpg with and_exp.1.jpg
# 4. Comparing face dav_exp.13.jpg with and_exp.1.jpg
# 5. Comparing face den_exp.13.jpg with and_exp.1.jpg
# 6. Comparing face dlwise.17.jpg with and_exp.1.jpg
# 7. Comparing face glen_exp.13.jpg with and_exp.1.jpg
# 8. Comparing face gpreec.11.jpg with and_exp.1.jpg
# 9. Comparing face hmgula.12.jpg with and_exp.1.jpg
# 10. Comparing face ian_exp.13.jpg with and_exp.1.jpg
# 11. Comparing face ireloz.15.jpg with and_exp.1.jpg
# 12. Comparing face john_exp.13.jpg with and_exp.1.jpg
# 13. Comparing face lib_exp.13.jpg with and_exp.1.jpg
# 14. Comparing face mike_exp.13.jpg with and_exp.1.jpg
# 15. Comparing face oegill.14.jpg with and_exp.1.jpg
# 16. Comparing face pat_exp.13.jpg with and_exp.1.jpg
# 17. Comparing face rjwils.15.jpg with and_exp.1.jpg
# 18. Comparing face ste_exp.13.jpg with and_exp.1.jpg
# 19. Comparing face stu_exp.13.jpg with and_exp.1.jpg
# 20. Comparing face will_exp.13.jpg with and_exp.1.jpg
# 21. Comparing face and_exp.13.jpg with ant_exp.1.jpg
# 22. Comparing face ant_exp.13.jpg with ant_exp.1.jpg
# 23. Comparing face chr_exp.13.jpg with ant_exp.1.jpg
# 24. Comparing face dav_exp.13.jpg with ant_exp.1.jpg
# 25. Comparing face den_exp.13.jpg with ant_exp.1.jpg
# 26. Comparing face dlwise.17.jpg with ant_exp.1.jpg
# 27. Comparing face glen_exp.13.jpg with ant_exp.1.jpg
# 28. Comparing face gpreec.11.jpg with ant_exp.1.jpg
# 29. Comparing face hmgula.12.jpg with ant_exp.1.jpg
# 30. Comparing face ian_exp.13.jpg with ant_exp.1.jpg
# 31. Comparing face ireloz.15.jpg with ant_exp.1.jpg
# 32. Comparing face john_exp.13.jpg with ant_exp.1.jpg
# 33. Comparing face lib_exp.13.jpg with ant_exp.1.jpg
# 34. Comparing face mike_exp.13.jpg with ant_exp.1.jpg
# 35. Comparing face oegill.14.jpg with ant_exp.1.jpg
# 36. Comparing face pat_exp.13.jpg with ant_exp.1.jpg
# 37. Comparing face rjwils.15.jpg with ant_exp.1.jpg
# 38. Comparing face ste_exp.13.jpg with ant_exp.1.jpg
# 39. Comparing face stu_exp.13.jpg with ant_exp.1.jpg
# 40. Comparing face will_exp.13.jpg with ant_exp.1.jpg
# 41. Comparing face and_exp.13.jpg with chr_exp.1.jpg
# 42. Comparing face ant_exp.13.jpg with chr_exp.1.jpg
# 43. Comparing face chr_exp.13.jpg with chr_exp.1.jpg
# 44. Comparing face dav_exp.13.jpg with chr_exp.1.jpg
# 45. Comparing face den_exp.13.jpg with chr_exp.1.jpg
# 46. Comparing face dlwise.17.jpg with chr_exp.1.jpg
# 47. Comparing face glen_exp.13.jpg with chr_exp.1.jpg
# 48. Comparing face gpreec.11.jpg with chr_exp.1.jpg
# 49. Comparing face hmgula.12.jpg with chr_exp.1.jpg
# 50. Comparing face ian_exp.13.jpg with chr_exp.1.jpg
# 51. Comparing face ireloz.15.jpg with chr_exp.1.jpg
# 52. Comparing face john_exp.13.jpg with chr_exp.1.jpg
# 53. Comparing face lib_exp.13.jpg with chr_exp.1.jpg
# 54. Comparing face mike_exp.13.jpg with chr_exp.1.jpg
# 55. Comparing face oegill.14.jpg with chr_exp.1.jpg
# 56. Comparing face pat_exp.13.jpg with chr_exp.1.jpg
# 57. Comparing face rjwils.15.jpg with chr_exp.1.jpg
# 58. Comparing face ste_exp.13.jpg with chr_exp.1.jpg
# 59. Comparing face stu_exp.13.jpg with chr_exp.1.jpg
# 60. Comparing face will_exp.13.jpg with chr_exp.1.jpg
# 61. Comparing face and_exp.13.jpg with dav_exp.1.jpg
# 62. Comparing face ant_exp.13.jpg with dav_exp.1.jpg
# 63. Comparing face chr_exp.13.jpg with dav_exp.1.jpg
# 64. Comparing face dav_exp.13.jpg with dav_exp.1.jpg
# 65. Comparing face den_exp.13.jpg with dav_exp.1.jpg
# 66. Comparing face dlwise.17.jpg with dav_exp.1.jpg
# 67. Comparing face glen_exp.13.jpg with dav_exp.1.jpg
# 68. Comparing face gpreec.11.jpg with dav_exp.1.jpg
# 69. Comparing face hmgula.12.jpg with dav_exp.1.jpg
# 70. Comparing face ian_exp.13.jpg with dav_exp.1.jpg
# 71. Comparing face ireloz.15.jpg with dav_exp.1.jpg
# 72. Comparing face john_exp.13.jpg with dav_exp.1.jpg
# 73. Comparing face lib_exp.13.jpg with dav_exp.1.jpg
# 74. Comparing face mike_exp.13.jpg with dav_exp.1.jpg
# 75. Comparing face oegill.14.jpg with dav_exp.1.jpg
# 76. Comparing face pat_exp.13.jpg with dav_exp.1.jpg
# 77. Comparing face rjwils.15.jpg with dav_exp.1.jpg
# 78. Comparing face ste_exp.13.jpg with dav_exp.1.jpg
# 79. Comparing face stu_exp.13.jpg with dav_exp.1.jpg
# 80. Comparing face will_exp.13.jpg with dav_exp.1.jpg
# 81. Comparing face and_exp.13.jpg with den_exp.1.jpg
# 82. Comparing face ant_exp.13.jpg with den_exp.1.jpg
# 83. Comparing face chr_exp.13.jpg with den_exp.1.jpg
# 84. Comparing face dav_exp.13.jpg with den_exp.1.jpg
# 85. Comparing face den_exp.13.jpg with den_exp.1.jpg
# 86. Comparing face dlwise.17.jpg with den_exp.1.jpg
# 87. Comparing face glen_exp.13.jpg with den_exp.1.jpg
# 88. Comparing face gpreec.11.jpg with den_exp.1.jpg
# 89. Comparing face hmgula.12.jpg with den_exp.1.jpg
# 90. Comparing face ian_exp.13.jpg with den_exp.1.jpg
# 91. Comparing face ireloz.15.jpg with den_exp.1.jpg
# 92. Comparing face john_exp.13.jpg with den_exp.1.jpg
# 93. Comparing face lib_exp.13.jpg with den_exp.1.jpg
# 94. Comparing face mike_exp.13.jpg with den_exp.1.jpg
# 95. Comparing face oegill.14.jpg with den_exp.1.jpg
# 96. Comparing face pat_exp.13.jpg with den_exp.1.jpg
# 97. Comparing face rjwils.15.jpg with den_exp.1.jpg
# 98. Comparing face ste_exp.13.jpg with den_exp.1.jpg
# 99. Comparing face stu_exp.13.jpg with den_exp.1.jpg
# 100. Comparing face will_exp.13.jpg with den_exp.1.jpg
# 101. Comparing face and_exp.13.jpg with dlwise.1.jpg
# 102. Comparing face ant_exp.13.jpg with dlwise.1.jpg
# 103. Comparing face chr_exp.13.jpg with dlwise.1.jpg
# 104. Comparing face dav_exp.13.jpg with dlwise.1.jpg
# 105. Comparing face den_exp.13.jpg with dlwise.1.jpg
# 106. Comparing face dlwise.17.jpg with dlwise.1.jpg
# 107. Comparing face glen_exp.13.jpg with dlwise.1.jpg
# 108. Comparing face gpreec.11.jpg with dlwise.1.jpg
# 109. Comparing face hmgula.12.jpg with dlwise.1.jpg
# 110. Comparing face ian_exp.13.jpg with dlwise.1.jpg
# 111. Comparing face ireloz.15.jpg with dlwise.1.jpg
# 112. Comparing face john_exp.13.jpg with dlwise.1.jpg
# 113. Comparing face lib_exp.13.jpg with dlwise.1.jpg
# 114. Comparing face mike_exp.13.jpg with dlwise.1.jpg
# 115. Comparing face oegill.14.jpg with dlwise.1.jpg
# 116. Comparing face pat_exp.13.jpg with dlwise.1.jpg
# 117. Comparing face rjwils.15.jpg with dlwise.1.jpg
# 118. Comparing face ste_exp.13.jpg with dlwise.1.jpg
# 119. Comparing face stu_exp.13.jpg with dlwise.1.jpg
# 120. Comparing face will_exp.13.jpg with dlwise.1.jpg
# 121. Comparing face and_exp.13.jpg with glen_exp.1.jpg
# 122. Comparing face ant_exp.13.jpg with glen_exp.1.jpg
# 123. Comparing face chr_exp.13.jpg with glen_exp.1.jpg
# 124. Comparing face dav_exp.13.jpg with glen_exp.1.jpg
# 125. Comparing face den_exp.13.jpg with glen_exp.1.jpg
# 126. Comparing face dlwise.17.jpg with glen_exp.1.jpg
# 127. Comparing face glen_exp.13.jpg with glen_exp.1.jpg
# 128. Comparing face gpreec.11.jpg with glen_exp.1.jpg
# 129. Comparing face hmgula.12.jpg with glen_exp.1.jpg
# 130. Comparing face ian_exp.13.jpg with glen_exp.1.jpg
# 131. Comparing face ireloz.15.jpg with glen_exp.1.jpg
# 132. Comparing face john_exp.13.jpg with glen_exp.1.jpg
# 133. Comparing face lib_exp.13.jpg with glen_exp.1.jpg
# 134. Comparing face mike_exp.13.jpg with glen_exp.1.jpg
# 135. Comparing face oegill.14.jpg with glen_exp.1.jpg
# 136. Comparing face pat_exp.13.jpg with glen_exp.1.jpg
# 137. Comparing face rjwils.15.jpg with glen_exp.1.jpg
# 138. Comparing face ste_exp.13.jpg with glen_exp.1.jpg
# 139. Comparing face stu_exp.13.jpg with glen_exp.1.jpg
# 140. Comparing face will_exp.13.jpg with glen_exp.1.jpg
# 141. Comparing face and_exp.13.jpg with gpreec.1.jpg
# 142. Comparing face ant_exp.13.jpg with gpreec.1.jpg
# 143. Comparing face chr_exp.13.jpg with gpreec.1.jpg
# 144. Comparing face dav_exp.13.jpg with gpreec.1.jpg
# 145. Comparing face den_exp.13.jpg with gpreec.1.jpg
# 146. Comparing face dlwise.17.jpg with gpreec.1.jpg
# 147. Comparing face glen_exp.13.jpg with gpreec.1.jpg
# 148. Comparing face gpreec.11.jpg with gpreec.1.jpg
# 149. Comparing face hmgula.12.jpg with gpreec.1.jpg
# 150. Comparing face ian_exp.13.jpg with gpreec.1.jpg
# 151. Comparing face ireloz.15.jpg with gpreec.1.jpg
# 152. Comparing face john_exp.13.jpg with gpreec.1.jpg
# 153. Comparing face lib_exp.13.jpg with gpreec.1.jpg
# 154. Comparing face mike_exp.13.jpg with gpreec.1.jpg
# 155. Comparing face oegill.14.jpg with gpreec.1.jpg
# 156. Comparing face pat_exp.13.jpg with gpreec.1.jpg
# 157. Comparing face rjwils.15.jpg with gpreec.1.jpg
# 158. Comparing face ste_exp.13.jpg with gpreec.1.jpg
# 159. Comparing face stu_exp.13.jpg with gpreec.1.jpg
# 160. Comparing face will_exp.13.jpg with gpreec.1.jpg
# 161. Comparing face and_exp.13.jpg with hmgula.1.jpg
# 162. Comparing face ant_exp.13.jpg with hmgula.1.jpg
# 163. Comparing face chr_exp.13.jpg with hmgula.1.jpg
# 164. Comparing face dav_exp.13.jpg with hmgula.1.jpg
# 165. Comparing face den_exp.13.jpg with hmgula.1.jpg
# 166. Comparing face dlwise.17.jpg with hmgula.1.jpg
# 167. Comparing face glen_exp.13.jpg with hmgula.1.jpg
# 168. Comparing face gpreec.11.jpg with hmgula.1.jpg
# 169. Comparing face hmgula.12.jpg with hmgula.1.jpg
# 170. Comparing face ian_exp.13.jpg with hmgula.1.jpg
# 171. Comparing face ireloz.15.jpg with hmgula.1.jpg
# 172. Comparing face john_exp.13.jpg with hmgula.1.jpg
# 173. Comparing face lib_exp.13.jpg with hmgula.1.jpg
# 174. Comparing face mike_exp.13.jpg with hmgula.1.jpg
# 175. Comparing face oegill.14.jpg with hmgula.1.jpg
# 176. Comparing face pat_exp.13.jpg with hmgula.1.jpg
# 177. Comparing face rjwils.15.jpg with hmgula.1.jpg
# 178. Comparing face ste_exp.13.jpg with hmgula.1.jpg
# 179. Comparing face stu_exp.13.jpg with hmgula.1.jpg
# 180. Comparing face will_exp.13.jpg with hmgula.1.jpg
# 181. Comparing face and_exp.13.jpg with ian_exp.1.jpg
# 182. Comparing face ant_exp.13.jpg with ian_exp.1.jpg
# 183. Comparing face chr_exp.13.jpg with ian_exp.1.jpg
# 184. Comparing face dav_exp.13.jpg with ian_exp.1.jpg
# 185. Comparing face den_exp.13.jpg with ian_exp.1.jpg
# 186. Comparing face dlwise.17.jpg with ian_exp.1.jpg
# 187. Comparing face glen_exp.13.jpg with ian_exp.1.jpg
# 188. Comparing face gpreec.11.jpg with ian_exp.1.jpg
# 189. Comparing face hmgula.12.jpg with ian_exp.1.jpg
# 190. Comparing face ian_exp.13.jpg with ian_exp.1.jpg
# 191. Comparing face ireloz.15.jpg with ian_exp.1.jpg
# 192. Comparing face john_exp.13.jpg with ian_exp.1.jpg
# 193. Comparing face lib_exp.13.jpg with ian_exp.1.jpg
# 194. Comparing face mike_exp.13.jpg with ian_exp.1.jpg
# 195. Comparing face oegill.14.jpg with ian_exp.1.jpg
# 196. Comparing face pat_exp.13.jpg with ian_exp.1.jpg
# 197. Comparing face rjwils.15.jpg with ian_exp.1.jpg
# 198. Comparing face ste_exp.13.jpg with ian_exp.1.jpg
# 199. Comparing face stu_exp.13.jpg with ian_exp.1.jpg
# 200. Comparing face will_exp.13.jpg with ian_exp.1.jpg
# 201. Comparing face and_exp.13.jpg with ireloz.10.jpg
# 202. Comparing face ant_exp.13.jpg with ireloz.10.jpg
# 203. Comparing face chr_exp.13.jpg with ireloz.10.jpg
# 204. Comparing face dav_exp.13.jpg with ireloz.10.jpg
# 205. Comparing face den_exp.13.jpg with ireloz.10.jpg
# 206. Comparing face dlwise.17.jpg with ireloz.10.jpg
# 207. Comparing face glen_exp.13.jpg with ireloz.10.jpg
# 208. Comparing face gpreec.11.jpg with ireloz.10.jpg
# 209. Comparing face hmgula.12.jpg with ireloz.10.jpg
# 210. Comparing face ian_exp.13.jpg with ireloz.10.jpg
# 211. Comparing face ireloz.15.jpg with ireloz.10.jpg
# 212. Comparing face john_exp.13.jpg with ireloz.10.jpg
# 213. Comparing face lib_exp.13.jpg with ireloz.10.jpg
# 214. Comparing face mike_exp.13.jpg with ireloz.10.jpg
# 215. Comparing face oegill.14.jpg with ireloz.10.jpg
# 216. Comparing face pat_exp.13.jpg with ireloz.10.jpg
# 217. Comparing face rjwils.15.jpg with ireloz.10.jpg
# 218. Comparing face ste_exp.13.jpg with ireloz.10.jpg
# 219. Comparing face stu_exp.13.jpg with ireloz.10.jpg
# 220. Comparing face will_exp.13.jpg with ireloz.10.jpg
# 221. Comparing face and_exp.13.jpg with john_exp.1.jpg
# 222. Comparing face ant_exp.13.jpg with john_exp.1.jpg
# 223. Comparing face chr_exp.13.jpg with john_exp.1.jpg
# 224. Comparing face dav_exp.13.jpg with john_exp.1.jpg
# 225. Comparing face den_exp.13.jpg with john_exp.1.jpg
# 226. Comparing face dlwise.17.jpg with john_exp.1.jpg
# 227. Comparing face glen_exp.13.jpg with john_exp.1.jpg
# 228. Comparing face gpreec.11.jpg with john_exp.1.jpg
# 229. Comparing face hmgula.12.jpg with john_exp.1.jpg
# 230. Comparing face ian_exp.13.jpg with john_exp.1.jpg
# 231. Comparing face ireloz.15.jpg with john_exp.1.jpg
# 232. Comparing face john_exp.13.jpg with john_exp.1.jpg
# 233. Comparing face lib_exp.13.jpg with john_exp.1.jpg
# 234. Comparing face mike_exp.13.jpg with john_exp.1.jpg
# 235. Comparing face oegill.14.jpg with john_exp.1.jpg
# 236. Comparing face pat_exp.13.jpg with john_exp.1.jpg
# 237. Comparing face rjwils.15.jpg with john_exp.1.jpg
# 238. Comparing face ste_exp.13.jpg with john_exp.1.jpg
# 239. Comparing face stu_exp.13.jpg with john_exp.1.jpg
# 240. Comparing face will_exp.13.jpg with john_exp.1.jpg
# 241. Comparing face and_exp.13.jpg with lib_exp.1.jpg
# 242. Comparing face ant_exp.13.jpg with lib_exp.1.jpg
# 243. Comparing face chr_exp.13.jpg with lib_exp.1.jpg
# 244. Comparing face dav_exp.13.jpg with lib_exp.1.jpg
# 245. Comparing face den_exp.13.jpg with lib_exp.1.jpg
# 246. Comparing face dlwise.17.jpg with lib_exp.1.jpg
# 247. Comparing face glen_exp.13.jpg with lib_exp.1.jpg
# 248. Comparing face gpreec.11.jpg with lib_exp.1.jpg
# 249. Comparing face hmgula.12.jpg with lib_exp.1.jpg
# 250. Comparing face ian_exp.13.jpg with lib_exp.1.jpg
# 251. Comparing face ireloz.15.jpg with lib_exp.1.jpg
# 252. Comparing face john_exp.13.jpg with lib_exp.1.jpg
# 253. Comparing face lib_exp.13.jpg with lib_exp.1.jpg
# 254. Comparing face mike_exp.13.jpg with lib_exp.1.jpg
# 255. Comparing face oegill.14.jpg with lib_exp.1.jpg
# 256. Comparing face pat_exp.13.jpg with lib_exp.1.jpg
# 257. Comparing face rjwils.15.jpg with lib_exp.1.jpg
# 258. Comparing face ste_exp.13.jpg with lib_exp.1.jpg
# 259. Comparing face stu_exp.13.jpg with lib_exp.1.jpg
# 260. Comparing face will_exp.13.jpg with lib_exp.1.jpg
# 261. Comparing face and_exp.13.jpg with mike_exp.1.jpg
# 262. Comparing face ant_exp.13.jpg with mike_exp.1.jpg
# 263. Comparing face chr_exp.13.jpg with mike_exp.1.jpg
# 264. Comparing face dav_exp.13.jpg with mike_exp.1.jpg
# 265. Comparing face den_exp.13.jpg with mike_exp.1.jpg
# 266. Comparing face dlwise.17.jpg with mike_exp.1.jpg
# 267. Comparing face glen_exp.13.jpg with mike_exp.1.jpg
# 268. Comparing face gpreec.11.jpg with mike_exp.1.jpg
# 269. Comparing face hmgula.12.jpg with mike_exp.1.jpg
# 270. Comparing face ian_exp.13.jpg with mike_exp.1.jpg
# 271. Comparing face ireloz.15.jpg with mike_exp.1.jpg
# 272. Comparing face john_exp.13.jpg with mike_exp.1.jpg
# 273. Comparing face lib_exp.13.jpg with mike_exp.1.jpg
# 274. Comparing face mike_exp.13.jpg with mike_exp.1.jpg
# 275. Comparing face oegill.14.jpg with mike_exp.1.jpg
# 276. Comparing face pat_exp.13.jpg with mike_exp.1.jpg
# 277. Comparing face rjwils.15.jpg with mike_exp.1.jpg
# 278. Comparing face ste_exp.13.jpg with mike_exp.1.jpg
# 279. Comparing face stu_exp.13.jpg with mike_exp.1.jpg
# 280. Comparing face will_exp.13.jpg with mike_exp.1.jpg
# 281. Comparing face and_exp.13.jpg with oegill.11.jpg
# 282. Comparing face ant_exp.13.jpg with oegill.11.jpg
# 283. Comparing face chr_exp.13.jpg with oegill.11.jpg
# 284. Comparing face dav_exp.13.jpg with oegill.11.jpg
# 285. Comparing face den_exp.13.jpg with oegill.11.jpg
# 286. Comparing face dlwise.17.jpg with oegill.11.jpg
# 287. Comparing face glen_exp.13.jpg with oegill.11.jpg
# 288. Comparing face gpreec.11.jpg with oegill.11.jpg
# 289. Comparing face hmgula.12.jpg with oegill.11.jpg
# 290. Comparing face ian_exp.13.jpg with oegill.11.jpg
# 291. Comparing face ireloz.15.jpg with oegill.11.jpg
# 292. Comparing face john_exp.13.jpg with oegill.11.jpg
# 293. Comparing face lib_exp.13.jpg with oegill.11.jpg
# 294. Comparing face mike_exp.13.jpg with oegill.11.jpg
# 295. Comparing face oegill.14.jpg with oegill.11.jpg
# 296. Comparing face pat_exp.13.jpg with oegill.11.jpg
# 297. Comparing face rjwils.15.jpg with oegill.11.jpg
# 298. Comparing face ste_exp.13.jpg with oegill.11.jpg
# 299. Comparing face stu_exp.13.jpg with oegill.11.jpg
# 300. Comparing face will_exp.13.jpg with oegill.11.jpg
# 301. Comparing face and_exp.13.jpg with pat_exp.1.jpg
# 302. Comparing face ant_exp.13.jpg with pat_exp.1.jpg
# 303. Comparing face chr_exp.13.jpg with pat_exp.1.jpg
# 304. Comparing face dav_exp.13.jpg with pat_exp.1.jpg
# 305. Comparing face den_exp.13.jpg with pat_exp.1.jpg
# 306. Comparing face dlwise.17.jpg with pat_exp.1.jpg
# 307. Comparing face glen_exp.13.jpg with pat_exp.1.jpg
# 308. Comparing face gpreec.11.jpg with pat_exp.1.jpg
# 309. Comparing face hmgula.12.jpg with pat_exp.1.jpg
# 310. Comparing face ian_exp.13.jpg with pat_exp.1.jpg
# 311. Comparing face ireloz.15.jpg with pat_exp.1.jpg
# 312. Comparing face john_exp.13.jpg with pat_exp.1.jpg
# 313. Comparing face lib_exp.13.jpg with pat_exp.1.jpg
# 314. Comparing face mike_exp.13.jpg with pat_exp.1.jpg
# 315. Comparing face oegill.14.jpg with pat_exp.1.jpg
# 316. Comparing face pat_exp.13.jpg with pat_exp.1.jpg
# 317. Comparing face rjwils.15.jpg with pat_exp.1.jpg
# 318. Comparing face ste_exp.13.jpg with pat_exp.1.jpg
# 319. Comparing face stu_exp.13.jpg with pat_exp.1.jpg
# 320. Comparing face will_exp.13.jpg with pat_exp.1.jpg
# 321. Comparing face and_exp.13.jpg with rjwils.12.jpg
# 322. Comparing face ant_exp.13.jpg with rjwils.12.jpg
# 323. Comparing face chr_exp.13.jpg with rjwils.12.jpg
# 324. Comparing face dav_exp.13.jpg with rjwils.12.jpg
# 325. Comparing face den_exp.13.jpg with rjwils.12.jpg
# 326. Comparing face dlwise.17.jpg with rjwils.12.jpg
# 327. Comparing face glen_exp.13.jpg with rjwils.12.jpg
# 328. Comparing face gpreec.11.jpg with rjwils.12.jpg
# 329. Comparing face hmgula.12.jpg with rjwils.12.jpg
# 330. Comparing face ian_exp.13.jpg with rjwils.12.jpg
# 331. Comparing face ireloz.15.jpg with rjwils.12.jpg
# 332. Comparing face john_exp.13.jpg with rjwils.12.jpg
# 333. Comparing face lib_exp.13.jpg with rjwils.12.jpg
# 334. Comparing face mike_exp.13.jpg with rjwils.12.jpg
# 335. Comparing face oegill.14.jpg with rjwils.12.jpg
# 336. Comparing face pat_exp.13.jpg with rjwils.12.jpg
# 337. Comparing face rjwils.15.jpg with rjwils.12.jpg
# 338. Comparing face ste_exp.13.jpg with rjwils.12.jpg
# 339. Comparing face stu_exp.13.jpg with rjwils.12.jpg
# 340. Comparing face will_exp.13.jpg with rjwils.12.jpg
# 341. Comparing face and_exp.13.jpg with ste_exp.1.jpg
# 342. Comparing face ant_exp.13.jpg with ste_exp.1.jpg
# 343. Comparing face chr_exp.13.jpg with ste_exp.1.jpg
# 344. Comparing face dav_exp.13.jpg with ste_exp.1.jpg
# 345. Comparing face den_exp.13.jpg with ste_exp.1.jpg
# 346. Comparing face dlwise.17.jpg with ste_exp.1.jpg
# 347. Comparing face glen_exp.13.jpg with ste_exp.1.jpg
# 348. Comparing face gpreec.11.jpg with ste_exp.1.jpg
# 349. Comparing face hmgula.12.jpg with ste_exp.1.jpg
# 350. Comparing face ian_exp.13.jpg with ste_exp.1.jpg
# 351. Comparing face ireloz.15.jpg with ste_exp.1.jpg
# 352. Comparing face john_exp.13.jpg with ste_exp.1.jpg
# 353. Comparing face lib_exp.13.jpg with ste_exp.1.jpg
# 354. Comparing face mike_exp.13.jpg with ste_exp.1.jpg
# 355. Comparing face oegill.14.jpg with ste_exp.1.jpg
# 356. Comparing face pat_exp.13.jpg with ste_exp.1.jpg
# 357. Comparing face rjwils.15.jpg with ste_exp.1.jpg
# 358. Comparing face ste_exp.13.jpg with ste_exp.1.jpg
# 359. Comparing face stu_exp.13.jpg with ste_exp.1.jpg
# 360. Comparing face will_exp.13.jpg with ste_exp.1.jpg
# 361. Comparing face and_exp.13.jpg with stu_exp.1.jpg
# 362. Comparing face ant_exp.13.jpg with stu_exp.1.jpg
# 363. Comparing face chr_exp.13.jpg with stu_exp.1.jpg
# 364. Comparing face dav_exp.13.jpg with stu_exp.1.jpg
# 365. Comparing face den_exp.13.jpg with stu_exp.1.jpg
# 366. Comparing face dlwise.17.jpg with stu_exp.1.jpg
# 367. Comparing face glen_exp.13.jpg with stu_exp.1.jpg
# 368. Comparing face gpreec.11.jpg with stu_exp.1.jpg
# 369. Comparing face hmgula.12.jpg with stu_exp.1.jpg
# 370. Comparing face ian_exp.13.jpg with stu_exp.1.jpg
# 371. Comparing face ireloz.15.jpg with stu_exp.1.jpg
# 372. Comparing face john_exp.13.jpg with stu_exp.1.jpg
# 373. Comparing face lib_exp.13.jpg with stu_exp.1.jpg
# 374. Comparing face mike_exp.13.jpg with stu_exp.1.jpg
# 375. Comparing face oegill.14.jpg with stu_exp.1.jpg
# 376. Comparing face pat_exp.13.jpg with stu_exp.1.jpg
# 377. Comparing face rjwils.15.jpg with stu_exp.1.jpg
# 378. Comparing face ste_exp.13.jpg with stu_exp.1.jpg
# 379. Comparing face stu_exp.13.jpg with stu_exp.1.jpg
# 380. Comparing face will_exp.13.jpg with stu_exp.1.jpg
# 381. Comparing face and_exp.13.jpg with will_exp.1.jpg
# 382. Comparing face ant_exp.13.jpg with will_exp.1.jpg
# 383. Comparing face chr_exp.13.jpg with will_exp.1.jpg
# 384. Comparing face dav_exp.13.jpg with will_exp.1.jpg
# 385. Comparing face den_exp.13.jpg with will_exp.1.jpg
# 386. Comparing face dlwise.17.jpg with will_exp.1.jpg
# 387. Comparing face glen_exp.13.jpg with will_exp.1.jpg
# 388. Comparing face gpreec.11.jpg with will_exp.1.jpg
# 389. Comparing face hmgula.12.jpg with will_exp.1.jpg
# 390. Comparing face ian_exp.13.jpg with will_exp.1.jpg
# 391. Comparing face ireloz.15.jpg with will_exp.1.jpg
# 392. Comparing face john_exp.13.jpg with will_exp.1.jpg
# 393. Comparing face lib_exp.13.jpg with will_exp.1.jpg
# 394. Comparing face mike_exp.13.jpg with will_exp.1.jpg
# 395. Comparing face oegill.14.jpg with will_exp.1.jpg
# 396. Comparing face pat_exp.13.jpg with will_exp.1.jpg
# 397. Comparing face rjwils.15.jpg with will_exp.1.jpg
# 398. Comparing face ste_exp.13.jpg with will_exp.1.jpg
# 399. Comparing face stu_exp.13.jpg with will_exp.1.jpg
# 400. Comparing face will_exp.13.jpg with will_exp.1.jpg
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-48-4cb0cc432e45> in <module>()
#      30         aws_comparison = aws_identification(BUCKET, S3_FOLDER + source_image_name,
#      31                                             BUCKET, S3_FOLDER + target_image_name,
# ---> 32                                             rekognition)
#      33         t3 = time.time()
#      34
#
# <ipython-input-43-5468eff693f6> in aws_identification(source_bucket, source_image, target_bucket, target_image, rekognition_client, threshold)
#      13             }
#      14         },
# ---> 15         SimilarityThreshold = threshold,
#      16     )
#      17     match = response['FaceMatches']
#
# ~/miniconda3/envs/python3/lib/python3.5/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     312                     "%s() only accepts keyword arguments." % py_operation_name)
#     313             # The "self" in this scope is referring to the BaseClient.
# --> 314             return self._make_api_call(operation_name, kwargs)
#     315
#     316         _api_call.__name__ = str(py_operation_name)
#
# ~/miniconda3/envs/python3/lib/python3.5/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     610             error_code = parsed_response.get("Error", {}).get("Code")
#     611             error_class = self.exceptions.from_code(error_code)
# --> 612             raise error_class(parsed_response, operation_name)
#     613         else:
#     614             return parsed_response
#
# ClientError: An error occurred (ExpiredTokenException) when calling the CompareFaces operation: The security token included in the request is expired

# %%
print("Dlib face identification success rate (it should be 1): " + str(dlib_success/n_different_people))
print("Amazon Rekognition face identification success rate (it should be 1): " + str(dlib_success/n_different_people))
# Out:
# Dlib face identification success rate (it should be 1): 1.0
# Amazon Rekognition face identification success rate (it should be 1): 1.0

# %%
f = open("Times/dlib_identification_times.txt","w") 
f.writelines('{}'.format(dlib_times))
f.close()

g = open("Times/aws_identification_times.txt","w") 
g.writelines('{}'.format(aws_times))
g.close()
