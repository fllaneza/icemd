# %% [markdown]
# # Amazon Rekognition: Face Verification

# %%
import boto3
import botocore
import numpy as np
from skimage import io
from os import getcwd, listdir
import time

PROFILE = "default"
BUCKET = "poc-images-rekognition"
DATA_FOLDER = "../Data/Recognition/"
SAVE_FOLDER = DATA_FOLDER + "Verification/"
REGION = "eu-west-1"
S3_FOLDER = "Recognition/"

# %%
session = boto3.Session(profile_name=PROFILE)
s3 = session.client("s3")
rekognition = session.client("rekognition", REGION)

# %%
files = listdir(DATA_FOLDER, )
images_names = sorted([f for f in files if f.endswith('.jpg')])
images = [io.imread(DATA_FOLDER + image) for image in images_names]
n_images = len(images)

# %%
def aws_verification(source_bucket, source_image, target_bucket, target_image, rekognition_client, threshold=80):
    response = rekognition_client.compare_faces(
        SourceImage={
            "S3Object": {
                "Bucket": source_bucket,
                "Name": source_image,
            }
        },
        TargetImage={
            "S3Object": {
                "Bucket": target_bucket,
                "Name": target_image,
            }
        },
        SimilarityThreshold = threshold,
    )
    match = response['FaceMatches']
    if not match: 
        verification_ok = False
    else:
        verification_ok = True
        
    return verification_ok

# %%
def concatenate_images(images, verbose = False): 
    n_images = len(images)
    images_dim = np.asarray([images[i].shape for i in range(0, n_images)])
    max_rows = max(images_dim[:,0])
    max_cols = max(images_dim[:,1])
    pad_images = list()
    
    if verbose:  
        print("")
        print("############################################################")
        print("Images dimensions: ") 
        print(images_dim)
        print("")
        print("Paddings: " + "[pad_top, pad_bottom, pad_left, pad_right]")
    
    for i in range(0, n_images):
        n_rows = images[i].shape[0]
        n_cols = images[i].shape[1]
        pad_top = pad_bottom = (max_rows - n_rows)//2
        pad_left = pad_right = (max_cols - n_cols)//2
        
        if verbose:
            print(str(i) + ". " + str([pad_top, pad_bottom, pad_left, pad_right]))
        
        if (pad_top + pad_bottom + pad_left + pad_right) !=0:
            
            if (pad_top + pad_bottom + n_rows) != max_rows:
                pad_top += 1
            
            if (pad_left + pad_right + n_cols) != max_cols:
                pad_left += 1
             
            pad_image = np.lib.pad(images[i], 
                            (
                                (pad_top, pad_bottom),
                                (pad_left, pad_right),
                                (0,0)
                            ), 
                            'constant', 
                            constant_values = 255) 
            pad_images.append(pad_image)
            
        else:
            pad_images.append(images[i])

    pad_images = np.asarray(pad_images)
    concat_images = np.hstack(pad_images)
    
    if verbose:
            print("################################################################")
    
    return concat_images

# %%
def random_images(images, out_inds, n_random_images = 5): 
    n_images = len(images)
    permutation = np.random.permutation([i for i in range(0, n_images) if i not in out_inds])
    n_first_inds = permutation[0:n_random_images]
    return n_first_inds, [images[i] for i in n_first_inds]

# %%
equal_image = io.imread('../Data/Symbols/Equal.jpg')
if equal_image.ndim != 3: 
    equal_image = np.repeat(equal_image[:, :, np.newaxis], 3, axis = 2)

not_equal_image = io.imread('../Data/Symbols/NotEqual.jpg')
if not_equal_image.ndim != 3: 
    not_equal_image = np.repeat(not_equal_image[:, :, np.newaxis], 3, axis = 2)

# %%
permutation = np.random.permutation([i for i in range(0, n_images) if i not in out_inds])
permutation
# Out:
# array([84,  2,  7, 82, 91, 68, 96, 30, 81, 59, 38, 25, 71, 78, 64, 62, 18,
#        48, 58, 37, 61, 56, 86, 49, 66, 99, 98, 39, 53, 29, 20, 89, 67,  9,
#        47, 65, 16, 34, 42, 77, 19, 70, 83, 41, 52, 12, 27, 32, 44, 35, 33,
#         3, 95, 74,  0, 90,  1, 85, 43, 93, 26, 60,  4, 88, 15, 28, 45, 11,
#        50, 97, 80, 72, 10, 63, 94, 69,  8,  5, 55, 46,  6, 13, 54, 79, 57,
#        14, 40, 73, 17, 51, 31, 92, 36, 76, 87, 75])

# %%
dlib_times = list()
aws_times = list()
dlib_matches = 0
aws_matches = 0
count = 0

n_persons = 20
n_faces_per_person = 5
n_random_images = 4

# win = dlib.image_window()

for i in range(0, n_persons):
    
    j = n_faces_per_person * i
    
    target_image = images[j]
    target_image_name = images_names[j]
    
    pos_match_source_images = images[(j+1):(j+n_faces_per_person)]
    pos_match_source_images_names = images_names[(j+1):(j+n_faces_per_person)]
    
    random_inds, neg_match_source_images = random_images(images, 
                                                         out_inds = range(j, j+n_faces_per_person), 
                                                         n_random_images = n_random_images)
    neg_match_source_images_names = [images_names[ind] for ind in random_inds]
    
    source_images = pos_match_source_images + neg_match_source_images
    source_images_names = pos_match_source_images_names + neg_match_source_images_names
    
    for k in range(len(source_images)):
    
        count += 1
        source_image = source_images[k]
        source_image_name = source_images_names[k]
             
        print("{}. Comparing face {} with {}".format(count, source_image_name, target_image_name))
        t1 = time.time()
        dlib_comparison = dlib_verification(source_image, target_image)
        t2 = time.time()
        aws_comparison = aws_verification(BUCKET, S3_FOLDER + source_image_name, 
                                          BUCKET, S3_FOLDER + target_image_name, 
                                          rekognition)
        t3 = time.time()

        dlib_times.append(t2-t1)
        aws_times.append(t3-t2)

        if dlib_comparison is True:
            dlib_matches += 1
            dlib_result = concatenate_images([source_image, equal_image, target_image])
        else:
            dlib_result = concatenate_images([source_image, not_equal_image, target_image])

        if aws_comparison is True:
            aws_matches += 1
            aws_result = concatenate_images([source_image, equal_image, target_image])
        else:
            aws_result = concatenate_images([source_image, not_equal_image, target_image])

        io.imsave(SAVE_FOLDER + "dlib_comparison_" + str(count) + ".jpg", dlib_result)
        io.imsave(SAVE_FOLDER + "aws_comparison_" + str(count) + ".jpg", aws_result)

        # win.clear_overlay()
        # win.set_image(image)
        # win.add_overlay(dlib_bounding_checks, dlib.rgb_pixel(0,0,255))
        # win.add_overlay(aws_bounding_checks)
# Out:
# 1. Comparing face and_exp.13.jpg with and_exp.1.jpg
# 2. Comparing face and_exp.17.jpg with and_exp.1.jpg
# 3. Comparing face and_exp.19.jpg with and_exp.1.jpg
# 4. Comparing face and_exp.3.jpg with and_exp.1.jpg
# 5. Comparing face ste_exp.13.jpg with and_exp.1.jpg
# 6. Comparing face ian_exp.3.jpg with and_exp.1.jpg
# 7. Comparing face hmgula.6.jpg with and_exp.1.jpg
# 8. Comparing face glen_exp.1.jpg with and_exp.1.jpg
# 9. Comparing face ant_exp.13.jpg with ant_exp.1.jpg
# 10. Comparing face ant_exp.17.jpg with ant_exp.1.jpg
# 11. Comparing face ant_exp.19.jpg with ant_exp.1.jpg
# 12. Comparing face ant_exp.3.jpg with ant_exp.1.jpg
# 13. Comparing face mike_exp.19.jpg with ant_exp.1.jpg
# 14. Comparing face hmgula.6.jpg with ant_exp.1.jpg
# 15. Comparing face ian_exp.13.jpg with ant_exp.1.jpg
# 16. Comparing face stu_exp.3.jpg with ant_exp.1.jpg
# 17. Comparing face chr_exp.13.jpg with chr_exp.1.jpg
# 18. Comparing face chr_exp.17.jpg with chr_exp.1.jpg
# 19. Comparing face chr_exp.19.jpg with chr_exp.1.jpg
# 20. Comparing face chr_exp.3.jpg with chr_exp.1.jpg
# 21. Comparing face will_exp.13.jpg with chr_exp.1.jpg
# 22. Comparing face ireloz.2.jpg with chr_exp.1.jpg
# 23. Comparing face hmgula.20.jpg with chr_exp.1.jpg
# 24. Comparing face den_exp.19.jpg with chr_exp.1.jpg
# 25. Comparing face dav_exp.13.jpg with dav_exp.1.jpg
# 26. Comparing face dav_exp.17.jpg with dav_exp.1.jpg
# 27. Comparing face dav_exp.19.jpg with dav_exp.1.jpg
# 28. Comparing face dav_exp.3.jpg with dav_exp.1.jpg
# 29. Comparing face ant_exp.3.jpg with dav_exp.1.jpg
# 30. Comparing face glen_exp.17.jpg with dav_exp.1.jpg
# 31. Comparing face john_exp.1.jpg with dav_exp.1.jpg
# 32. Comparing face oegill.7.jpg with dav_exp.1.jpg
# 33. Comparing face den_exp.13.jpg with den_exp.1.jpg
# 34. Comparing face den_exp.17.jpg with den_exp.1.jpg
# 35. Comparing face den_exp.19.jpg with den_exp.1.jpg
# 36. Comparing face den_exp.3.jpg with den_exp.1.jpg
# 37. Comparing face dav_exp.1.jpg with den_exp.1.jpg
# 38. Comparing face mike_exp.17.jpg with den_exp.1.jpg
# 39. Comparing face ant_exp.19.jpg with den_exp.1.jpg
# 40. Comparing face chr_exp.3.jpg with den_exp.1.jpg
# 41. Comparing face dlwise.17.jpg with dlwise.1.jpg
# 42. Comparing face dlwise.19.jpg with dlwise.1.jpg
# 43. Comparing face dlwise.20.jpg with dlwise.1.jpg
# 44. Comparing face dlwise.5.jpg with dlwise.1.jpg
# 45. Comparing face stu_exp.13.jpg with dlwise.1.jpg
# 46. Comparing face john_exp.17.jpg with dlwise.1.jpg
# 47. Comparing face hmgula.20.jpg with dlwise.1.jpg
# 48. Comparing face and_exp.13.jpg with dlwise.1.jpg
# 49. Comparing face glen_exp.13.jpg with glen_exp.1.jpg
# 50. Comparing face glen_exp.17.jpg with glen_exp.1.jpg
# 51. Comparing face glen_exp.19.jpg with glen_exp.1.jpg
# 52. Comparing face glen_exp.3.jpg with glen_exp.1.jpg
# 53. Comparing face ant_exp.17.jpg with glen_exp.1.jpg
# 54. Comparing face oegill.11.jpg with glen_exp.1.jpg
# 55. Comparing face dav_exp.17.jpg with glen_exp.1.jpg
# 56. Comparing face ant_exp.13.jpg with glen_exp.1.jpg
# 57. Comparing face gpreec.11.jpg with gpreec.1.jpg
# 58. Comparing face gpreec.13.jpg with gpreec.1.jpg
# 59. Comparing face gpreec.16.jpg with gpreec.1.jpg
# 60. Comparing face gpreec.5.jpg with gpreec.1.jpg
# 61. Comparing face mike_exp.19.jpg with gpreec.1.jpg
# 62. Comparing face and_exp.3.jpg with gpreec.1.jpg
# 63. Comparing face rjwils.4.jpg with gpreec.1.jpg
# 64. Comparing face ireloz.2.jpg with gpreec.1.jpg
# 65. Comparing face hmgula.12.jpg with hmgula.1.jpg
# 66. Comparing face hmgula.13.jpg with hmgula.1.jpg
# 67. Comparing face hmgula.20.jpg with hmgula.1.jpg
# 68. Comparing face hmgula.6.jpg with hmgula.1.jpg
# 69. Comparing face dav_exp.3.jpg with hmgula.1.jpg
# 70. Comparing face gpreec.13.jpg with hmgula.1.jpg
# 71. Comparing face and_exp.17.jpg with hmgula.1.jpg
# 72. Comparing face den_exp.3.jpg with hmgula.1.jpg
# 73. Comparing face ian_exp.13.jpg with ian_exp.1.jpg
# 74. Comparing face ian_exp.17.jpg with ian_exp.1.jpg
# 75. Comparing face ian_exp.19.jpg with ian_exp.1.jpg
# 76. Comparing face ian_exp.3.jpg with ian_exp.1.jpg
# 77. Comparing face dlwise.5.jpg with ian_exp.1.jpg
# 78. Comparing face den_exp.17.jpg with ian_exp.1.jpg
# 79. Comparing face dav_exp.1.jpg with ian_exp.1.jpg
# 80. Comparing face will_exp.19.jpg with ian_exp.1.jpg
# 81. Comparing face ireloz.15.jpg with ireloz.10.jpg
# 82. Comparing face ireloz.2.jpg with ireloz.10.jpg
# 83. Comparing face ireloz.20.jpg with ireloz.10.jpg
# 84. Comparing face ireloz.4.jpg with ireloz.10.jpg
# 85. Comparing face ste_exp.17.jpg with ireloz.10.jpg
# 86. Comparing face ian_exp.3.jpg with ireloz.10.jpg
# 87. Comparing face oegill.20.jpg with ireloz.10.jpg
# 88. Comparing face ste_exp.19.jpg with ireloz.10.jpg
# 89. Comparing face john_exp.13.jpg with john_exp.1.jpg
# 90. Comparing face john_exp.17.jpg with john_exp.1.jpg
# 91. Comparing face john_exp.19.jpg with john_exp.1.jpg
# 92. Comparing face john_exp.3.jpg with john_exp.1.jpg
# 93. Comparing face dav_exp.13.jpg with john_exp.1.jpg
# 94. Comparing face lib_exp.13.jpg with john_exp.1.jpg
# 95. Comparing face will_exp.3.jpg with john_exp.1.jpg
# 96. Comparing face dav_exp.17.jpg with john_exp.1.jpg
# 97. Comparing face lib_exp.13.jpg with lib_exp.1.jpg
# 98. Comparing face lib_exp.17.jpg with lib_exp.1.jpg
# 99. Comparing face lib_exp.19.jpg with lib_exp.1.jpg
# 100. Comparing face lib_exp.3.jpg with lib_exp.1.jpg
# 101. Comparing face hmgula.6.jpg with lib_exp.1.jpg
# 102. Comparing face stu_exp.3.jpg with lib_exp.1.jpg
# 103. Comparing face rjwils.17.jpg with lib_exp.1.jpg
# 104. Comparing face rjwils.4.jpg with lib_exp.1.jpg
# 105. Comparing face mike_exp.13.jpg with mike_exp.1.jpg
# 106. Comparing face mike_exp.17.jpg with mike_exp.1.jpg
# 107. Comparing face mike_exp.19.jpg with mike_exp.1.jpg
# 108. Comparing face mike_exp.3.jpg with mike_exp.1.jpg
# 109. Comparing face den_exp.13.jpg with mike_exp.1.jpg
# 110. Comparing face glen_exp.3.jpg with mike_exp.1.jpg
# 111. Comparing face hmgula.6.jpg with mike_exp.1.jpg
# 112. Comparing face john_exp.1.jpg with mike_exp.1.jpg
# 113. Comparing face oegill.14.jpg with oegill.11.jpg
# 114. Comparing face oegill.20.jpg with oegill.11.jpg
# 115. Comparing face oegill.5.jpg with oegill.11.jpg
# 116. Comparing face oegill.7.jpg with oegill.11.jpg
# 117. Comparing face will_exp.17.jpg with oegill.11.jpg
# 118. Comparing face ste_exp.19.jpg with oegill.11.jpg
# 119. Comparing face will_exp.13.jpg with oegill.11.jpg
# 120. Comparing face ste_exp.1.jpg with oegill.11.jpg
# 121. Comparing face pat_exp.13.jpg with pat_exp.1.jpg
# 122. Comparing face pat_exp.17.jpg with pat_exp.1.jpg
# 123. Comparing face pat_exp.19.jpg with pat_exp.1.jpg
# 124. Comparing face pat_exp.3.jpg with pat_exp.1.jpg
# 125. Comparing face ireloz.20.jpg with pat_exp.1.jpg
# 126. Comparing face rjwils.15.jpg with pat_exp.1.jpg
# 127. Comparing face ste_exp.13.jpg with pat_exp.1.jpg
# 128. Comparing face lib_exp.19.jpg with pat_exp.1.jpg
# 129. Comparing face rjwils.15.jpg with rjwils.12.jpg
# 130. Comparing face rjwils.17.jpg with rjwils.12.jpg
# 131. Comparing face rjwils.4.jpg with rjwils.12.jpg
# 132. Comparing face rjwils.8.jpg with rjwils.12.jpg
# 133. Comparing face chr_exp.1.jpg with rjwils.12.jpg
# 134. Comparing face den_exp.13.jpg with rjwils.12.jpg
# 135. Comparing face ant_exp.3.jpg with rjwils.12.jpg
# 136. Comparing face dav_exp.3.jpg with rjwils.12.jpg
# 137. Comparing face ste_exp.13.jpg with ste_exp.1.jpg
# 138. Comparing face ste_exp.17.jpg with ste_exp.1.jpg
# 139. Comparing face ste_exp.19.jpg with ste_exp.1.jpg
# 140. Comparing face ste_exp.3.jpg with ste_exp.1.jpg
# 141. Comparing face ireloz.15.jpg with ste_exp.1.jpg
# 142. Comparing face glen_exp.3.jpg with ste_exp.1.jpg
# 143. Comparing face hmgula.1.jpg with ste_exp.1.jpg
# 144. Comparing face oegill.11.jpg with ste_exp.1.jpg
# 145. Comparing face stu_exp.13.jpg with stu_exp.1.jpg
# 146. Comparing face stu_exp.17.jpg with stu_exp.1.jpg
# 147. Comparing face stu_exp.19.jpg with stu_exp.1.jpg
# 148. Comparing face stu_exp.3.jpg with stu_exp.1.jpg
# 149. Comparing face hmgula.20.jpg with stu_exp.1.jpg
# 150. Comparing face hmgula.1.jpg with stu_exp.1.jpg
# 151. Comparing face ian_exp.19.jpg with stu_exp.1.jpg
# 152. Comparing face den_exp.19.jpg with stu_exp.1.jpg
# 153. Comparing face will_exp.13.jpg with will_exp.1.jpg
# 154. Comparing face will_exp.17.jpg with will_exp.1.jpg
# 155. Comparing face will_exp.19.jpg with will_exp.1.jpg
# 156. Comparing face will_exp.3.jpg with will_exp.1.jpg
# 157. Comparing face oegill.20.jpg with will_exp.1.jpg
# 158. Comparing face dav_exp.3.jpg with will_exp.1.jpg
# 159. Comparing face mike_exp.19.jpg with will_exp.1.jpg
# 160. Comparing face john_exp.3.jpg with will_exp.1.jpg

# %%
print("Dlib face verification percentage success: " + str(100*dlib_matches/count) + "%")
print("Amazon Rekognition face verification percentage success: " + str(100*aws_matches/count) + "%")
# Out:
# Dlib face verification percentage success: 49.375%
# Amazon Rekognition face verification percentage success: 50.0%

# %%
f = open("../Times/dlib_verification_times.txt","w") 
f.writelines('{}'.format(dlib_times))
f.close()

g = open("../Times/aws_verification_times.txt","w") 
g.writelines('{}'.format(aws_times))
g.close()
